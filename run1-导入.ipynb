# %%
# coding=utf-8
from __future__ import print_function, absolute_import
from gm.api import *
from datetime import datetime, date, timedelta
import pandas as pd
import numpy as np

set_token('1b1a89188ac160dc17d81400310c03e441d37b72')

# %%
lt_eqy_inv='mny_cptl,acct_rcv,invt,ttl_cur_ast,fix_ast,lt_eqy_inv,intg_ast,gw,ttl_ncur_ast,ttl_ast,sht_ln,acct_pay,ttl_cur_liab,lt_ln,ttl_ncur_liab,ttl_liab,cptl_rsv,ret_prof,ttl_eqy_pcom,ttl_eqy'
stk_get_fundamentals_balance(symbol='SHSE.600000', rpt_type=12, data_type=None, start_date='2022-12-31', end_date='2022-12-31', fields=lt_eqy_inv, df=True)
# Out:
#         symbol    pub_date    rpt_date        mny_cptl            gw  \
# 0  SHSE.600000  2023-04-19  2022-12-31  4.57089000e+11  6981000000.0
#
#    ttl_ncur_ast        ret_prof       cptl_rsv  rpt_type  acct_pay  ...  invt  \
# 0           NaN  2.03220000e+11  81762000000.0        12       NaN  ...   NaN
#
#           ttl_ast         ttl_eqy  lt_ln       intg_ast  sht_ln  ttl_cur_liab  \
# 0  8.70465100e+12  7.06775000e+11    NaN  10349000000.0     NaN           NaN
#
#          fix_ast  data_type    lt_eqy_inv
# 0  37157000000.0        100  2655000000.0
#
# [1 rows x 25 columns]

# %%
import akshare as ak

macro_usa_gdp_monthly_df = ak.macro_usa_gdp_monthly()
print(macro_usa_gdp_monthly_df)
# Out:
#                 商品          日期   今值  预测值   前值
# 0    美国国内生产总值(GDP)  2008-02-28  0.6  0.7  0.6
# 1    美国国内生产总值(GDP)  2008-03-27  0.6  0.6  0.6
# 2    美国国内生产总值(GDP)  2008-04-30  0.6  0.2  0.6
# 3    美国国内生产总值(GDP)  2008-06-26  2.7  1.0  0.9
# 4    美国国内生产总值(GDP)  2008-07-31  1.9  2.0  1.0
# ..             ...         ...  ...  ...  ...
# 205  美国国内生产总值(GDP)  2025-05-29 -0.2 -0.3  2.4
# 206  美国国内生产总值(GDP)  2025-06-26 -0.5 -0.2  2.4
# 207  美国国内生产总值(GDP)  2025-07-30  3.0  2.5 -0.5
# 208  美国国内生产总值(GDP)  2025-08-28  3.3  3.0 -0.5
# 209  美国国内生产总值(GDP)  2025-09-25  NaN  NaN  3.3
#
# [210 rows x 5 columns]

# %%
macro_usa_cpi_monthly_df = ak.macro_usa_cpi_monthly()
print(macro_usa_cpi_monthly_df)
# Out:
#           商品          日期   今值  预测值   前值
# 0    美国CPI月率  1970-01-01  0.5  NaN  NaN
# 1    美国CPI月率  1970-02-01  0.5  NaN  0.5
# 2    美国CPI月率  1970-03-01  0.5  NaN  0.5
# 3    美国CPI月率  1970-04-01  0.5  NaN  0.5
# 4    美国CPI月率  1970-05-01  0.5  NaN  0.5
# ..       ...         ...  ...  ...  ...
# 664  美国CPI月率  2025-05-13  0.2  0.3 -0.1
# 665  美国CPI月率  2025-06-11  0.1  0.2  0.2
# 666  美国CPI月率  2025-07-15  0.3  0.3  0.1
# 667  美国CPI月率  2025-08-12  0.2  0.2  0.3
# 668  美国CPI月率  2025-09-11  NaN  NaN  0.2
#
# [669 rows x 5 columns]

# %%
macro_usa_cpi_yoy_df = ak.macro_usa_cpi_yoy()
print(macro_usa_cpi_yoy_df)
# Out:
#              时间        发布日期   现值   前值
# 0    2008-01-01  2008-02-14  4.3  4.1
# 1    2008-02-01  2008-03-16  4.0  4.3
# 2    2008-03-01  2008-04-14  4.0  4.0
# 3    2008-04-01  2008-05-15  3.9  4.0
# 4    2008-05-01  2008-06-14  4.2  3.9
# ..          ...         ...  ...  ...
# 216  2026-02-01  2026-03-11  2.4  2.4
# 217  2026-03-01  2026-04-10  3.3  2.4
# 218  2026-04-01  2026-05-12  3.8  3.3
# 219  2026-05-01  2026-06-10  4.2  3.8
# 220  2026-06-01  2026-07-14  NaN  4.2
#
# [221 rows x 4 columns]

# %%
macro_usa_core_cpi_monthly_df = ak.macro_usa_core_cpi_monthly()
print(macro_usa_core_cpi_monthly_df)
# Out:
#             商品          日期   今值  预测值   前值
# 0    美国核心CPI月率  1970-01-01  0.5  NaN  NaN
# 1    美国核心CPI月率  1970-02-01  0.5  NaN  0.5
# 2    美国核心CPI月率  1970-03-01  0.5  NaN  0.5
# 3    美国核心CPI月率  1970-04-01  0.8  NaN  0.5
# 4    美国核心CPI月率  1970-05-01  0.7  NaN  0.8
# ..         ...         ...  ...  ...  ...
# 664  美国核心CPI月率  2025-05-13  0.2  0.3  0.1
# 665  美国核心CPI月率  2025-06-11  0.1  0.3  0.2
# 666  美国核心CPI月率  2025-07-15  0.2  0.3  0.1
# 667  美国核心CPI月率  2025-08-12  0.3  0.3  0.2
# 668  美国核心CPI月率  2025-09-11  NaN  NaN  0.3
#
# [669 rows x 5 columns]

# %%
macro_usa_unemployment_rate_df = ak.macro_usa_unemployment_rate()
print(macro_usa_unemployment_rate_df)
# Out:
#         商品          日期   今值  预测值   前值
# 0    美国失业率  1970-01-01  3.5  NaN  3.5
# 1    美国失业率  1970-02-01  3.9  NaN  3.5
# 2    美国失业率  1970-03-01  4.2  NaN  3.9
# 3    美国失业率  1970-04-01  4.4  NaN  4.2
# 4    美国失业率  1970-05-01  4.6  NaN  4.4
# ..     ...         ...  ...  ...  ...
# 664  美国失业率  2025-05-02  4.2  4.2  4.2
# 665  美国失业率  2025-06-06  4.2  4.2  4.2
# 666  美国失业率  2025-07-03  4.1  4.3  4.2
# 667  美国失业率  2025-08-01  4.2  4.2  4.1
# 668  美国失业率  2025-09-05  NaN  4.3  4.2
#
# [669 rows x 5 columns]

# %%
macro_usa_non_farm_df = ak.macro_usa_non_farm()
print(macro_usa_non_farm_df)
# Out:
#            商品          日期    今值   预测值    前值
# 0    美国非农就业人数  1970-01-02  15.3   NaN  -3.3
# 1    美国非农就业人数  1970-02-06  -6.4   NaN  15.3
# 2    美国非农就业人数  1970-03-06  12.8   NaN  -6.4
# 3    美国非农就业人数  1970-04-03  14.8   NaN  12.8
# 4    美国非农就业人数  1970-05-01 -10.4   NaN  14.8
# ..        ...         ...   ...   ...   ...
# 664  美国非农就业人数  2025-05-02  17.7  13.8  18.5
# 665  美国非农就业人数  2025-06-06  13.9  12.6  14.7
# 666  美国非农就业人数  2025-07-03  14.7  11.1  14.4
# 667  美国非农就业人数  2025-08-01   7.3  10.6   1.4
# 668  美国非农就业人数  2025-09-05   NaN   7.5   7.3
#
# [669 rows x 5 columns]

# %%
macro_usa_ppi_df = ak.macro_usa_ppi()
print(macro_usa_ppi_df)
# Out:
#             商品          日期   今值  预测值   前值
# 0    美国生产者物价指数  2008-02-26  1.0  0.4 -0.3
# 1    美国生产者物价指数  2008-03-18  0.3  0.3  1.0
# 2    美国生产者物价指数  2008-04-15  1.1  0.6  0.3
# 3    美国生产者物价指数  2008-05-20  0.2  0.4  1.1
# 4    美国生产者物价指数  2008-06-17  1.4  1.0  0.2
# ..         ...         ...  ...  ...  ...
# 208  美国生产者物价指数  2025-05-15 -0.5  0.2  0.0
# 209  美国生产者物价指数  2025-06-12  0.1  0.2 -0.2
# 210  美国生产者物价指数  2025-07-16  0.0  0.2  0.3
# 211  美国生产者物价指数  2025-08-14  0.9  0.2  0.0
# 212  美国生产者物价指数  2025-09-10  NaN  NaN  0.9
#
# [213 rows x 5 columns]

# %%
macro_usa_core_ppi_df = ak.macro_usa_core_ppi()
print(macro_usa_core_ppi_df)
# Out:
#               商品          日期   今值  预测值   前值
# 0    美国核心生产者物价指数  2008-03-18  0.5  0.2  0.4
# 1    美国核心生产者物价指数  2008-04-15  0.2  0.2  0.5
# 2    美国核心生产者物价指数  2008-05-20  0.4  0.2  0.2
# 3    美国核心生产者物价指数  2008-06-17  0.2  0.2  0.4
# 4    美国核心生产者物价指数  2008-08-19  0.7  0.2  0.2
# ..           ...         ...  ...  ...  ...
# 205  美国核心生产者物价指数  2025-05-15 -0.4  0.3  0.4
# 206  美国核心生产者物价指数  2025-06-12  0.1  0.3 -0.2
# 207  美国核心生产者物价指数  2025-07-16  0.0  0.2  0.4
# 208  美国核心生产者物价指数  2025-08-14  0.9  0.2  0.0
# 209  美国核心生产者物价指数  2025-09-10  NaN  NaN  0.9
#
# [210 rows x 5 columns]

# %%
macro_usa_pmi_df = ak.macro_usa_pmi()
print(macro_usa_pmi_df)
# Out:
#                    商品          日期    今值   预测值    前值
# 0    美国Markit制造业PMI报告  2012-06-01  54.0   NaN  53.9
# 1    美国Markit制造业PMI报告  2012-07-02  52.5  53.0  52.9
# 2    美国Markit制造业PMI报告  2012-07-24  51.8  52.1  52.5
# 3    美国Markit制造业PMI报告  2012-08-01  51.4  51.9  51.8
# 4    美国Markit制造业PMI报告  2012-08-23  51.9  51.3  51.4
# ..                ...         ...   ...   ...   ...
# 314  美国Markit制造业PMI报告  2025-07-24  49.5  52.7  52.9
# 315  美国Markit制造业PMI报告  2025-08-01  49.8  49.5  52.9
# 316  美国Markit制造业PMI报告  2025-08-21  53.3  49.7  49.8
# 317  美国Markit制造业PMI报告  2025-09-02  53.0  53.3  49.8
# 318  美国Markit制造业PMI报告  2025-09-23   NaN   NaN  53.0
#
# [319 rows x 5 columns]

# %%
macro_usa_ism_pmi_df = ak.macro_usa_ism_pmi()
print(macro_usa_ism_pmi_df)
# Out:
#                 商品          日期    今值   预测值    前值
# 0    美国ISM制造业PMI报告  1970-01-01  52.0   NaN   NaN
# 1    美国ISM制造业PMI报告  1970-02-01  48.7   NaN  52.0
# 2    美国ISM制造业PMI报告  1970-03-01  47.4   NaN  48.7
# 3    美国ISM制造业PMI报告  1970-04-01  46.9   NaN  47.4
# 4    美国ISM制造业PMI报告  1970-05-01  45.0   NaN  46.9
# ..             ...         ...   ...   ...   ...
# 666  美国ISM制造业PMI报告  2025-05-01  48.7  48.0  49.0
# 667  美国ISM制造业PMI报告  2025-06-02  48.5  49.3  48.7
# 668  美国ISM制造业PMI报告  2025-07-01  49.0  48.8  48.5
# 669  美国ISM制造业PMI报告  2025-08-01  48.0  49.5  49.0
# 670  美国ISM制造业PMI报告  2025-09-02  48.7  49.0  48.0
#
# [671 rows x 5 columns]

# %%
macro_usa_initial_jobless_df = ak.macro_usa_initial_jobless()
print(macro_usa_initial_jobless_df)
# Out:
#              商品          日期      今值   预测值      前值
# 0     美国初请失业金人数  1970-01-01  22.109   NaN     NaN
# 1     美国初请失业金人数  1970-02-01  24.932   NaN  22.109
# 2     美国初请失业金人数  1970-03-01  25.850   NaN  24.932
# 3     美国初请失业金人数  1970-04-01  26.868   NaN  25.850
# 4     美国初请失业金人数  1970-05-01  33.159   NaN  26.868
# ...         ...         ...     ...   ...     ...
# 1370  美国初请失业金人数  2025-08-14  22.400  22.5  22.700
# 1371  美国初请失业金人数  2025-08-21  23.500  22.6  22.400
# 1372  美国初请失业金人数  2025-08-28  22.900  23.1  23.400
# 1373  美国初请失业金人数  2025-09-04  23.700  23.0  22.900
# 1374  美国初请失业金人数  2025-09-11     NaN   NaN  23.700
#
# [1375 rows x 5 columns]

# %%
macro_info_ws_df = ak.macro_info_ws(date="20260701")
print(macro_info_ws_df)
# Out:
#                      时间  地区                        事件  重要性     今值  预期     前值  \
# 0   2026-07-01 00:00:00  中国        存储产品成本上涨，海康威视硬盘或调价    3    NaN NaN    NaN
# 1   2026-07-01 00:00:00  中国   埃夫特：旗下喷涂机器人全系列产品涨价5%—8%    3    NaN NaN    NaN
# 2   2026-07-01 00:00:00  中国      CCL大厂建滔等预计提价10%-15%     3    NaN NaN    NaN
# 3   2026-07-01 00:00:00  中国          日本酸素宣布氨气产品涨价超30%    3    NaN NaN    NaN
# 4   2026-07-01 00:00:00  中国           IC设计龙头联发科预计7月涨价    4    NaN NaN    NaN
# ..                  ...  ..                       ...  ...    ...  ..    ...
# 63  2026-07-01 22:30:00  美国     6月26日当周EIA精炼油库存变动(万桶)    2  248.3 NaN  306.4
# 64  2026-07-01 22:30:00  美国      6月26日当周EIA汽油库存变动(万桶)    2 -233.3 NaN  206.4
# 65  2026-07-01 22:30:00  美国  6月26日当周EIA库欣地区原油库存变动(万桶)    2   70.9 NaN -107.7
# 66  2026-07-01 22:30:00  美国      6月26日当周EIA原油库存变动(万桶)    2 -377.5 NaN -608.8
# 67  2026-07-02 00:00:00  中国             全球OPC共创节在北京举行    2    NaN NaN    NaN
#
#                                                    链接
# 0
# 1
# 2
# 3
# 4
# ..                                                ...
# 63  https://wallstreetcn.com/calendar/US141123/ove...
# 64  https://wallstreetcn.com/calendar/US141124/ove...
# 65  https://wallstreetcn.com/calendar/US141127/ove...
# 66  https://wallstreetcn.com/calendar/US141126/ove...
# 67
#
# [68 rows x 8 columns]

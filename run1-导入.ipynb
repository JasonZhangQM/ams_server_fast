# %%
from app.bills.service import *
from app.bds.service import *
from app.irs.service import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from app.bills.service import *
#       2 from app.bds.service import *
#       3 from app.irs.service import *
#
# File c:\mysite\ams_trae\server_fast\app\bills\service.py:24
#      21 from sqlalchemy import text, select, func
#      22 from decimal import Decimal
# ---> 24 from server_fast.config import settings
#      25 from server_fast.common.utils import (
#      26     filter_in_cols, map_value, filter_dtypes, df_init_model,
#      27     act_sql_engine, upsert_df_to_db, get_sql_to_df,
#      28 )
#      29 from server_fast.common.db import SessionLocal
#
# ModuleNotFoundError: No module named 'server_fast'

# %%
insert_trade_date_em_sql() # 交易日历数据
upsert_symbol_info_excel_sql() # 导入股票信息

# %%
insert_bill_all_excel_sql() # 导入账单数据
# insert_io_all_excel_sql() # 导入出入金数据

# %%
update_symbol_bill_sql() # 更新账单中的代码
del_old_symbol_group_sql() # 删除汇总表中的旧代码
upsert_group_cash_sql() # 资金汇总
upsert_group_profit_sql() # 收益汇总

# %%
upsert_profit_group_sql() #收益试算(需改进：不需要计算存量数据)
cash_update_group_sql() #资金试算(需改进：不需要计算存量数据)

# %%
upsert_daily_value_group_em_sql() #交易日结(需改进：不需要计算存量数据)
upsert_daily_cash_group_sql() #资金日结(需改进：不需要计算存量数据)

# %%
upsert_daily_acc_sql() #账户日结、月结、季节、年结
upsert_daily_all_sql() #日结、月结、季节、年结

# %%
upsert_group_acc_sql() #账户汇总

# %%
upsert_model_excel_sql( #估值数据
    IrsCfg.FOLDER_SYMBOL_VALUE,SymbolValue) 
upsert_model_excel_sql( #期权标的
    IrsCfg.FOLDER_OPTION,SymbolUnderlying) 
upsert_model_excel_sql( #贴水标的(导入连续合约)
    IrsCfg.FOLDER_SYMBOL_CON,SymbolDiscount)

# %%
update_symbol_value_hlc_sql() #更新估值配置中的行情数据

# %%
upsert_discount_em_sql() #连续合约信息完善(基础数据+主力标志)

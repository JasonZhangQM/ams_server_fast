# %%
import os
os.environ["TQDM_DISABLE"] = "1"  # 完全禁用进度条
import akshare as ak
from pathlib import Path
from gm.api import *
from config import settings

import sys
from pathlib import Path

# server_fast 的父目录
BASE = Path(r"c:\mysite\ams_trae")
if str(BASE) not in sys.path:
    sys.path.insert(0, str(BASE))

# %%
from app.bds.services.market_data.daily_mktvalue import _fetch_daily_mktvalue_batched

# %%
_fetch_daily_mktvalue_batched('SHSE.600000')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 _fetch_daily_mktvalue_batched('SHSE.600000')
#
# TypeError: _fetch_daily_mktvalue_batched() missing 2 required positional arguments: 'start_date' and 'end_date'
